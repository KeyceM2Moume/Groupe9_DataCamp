# %%
# !pip install google_play_scraper

# %%
import pandas as pd
from google_play_scraper import reviews, reviews_all, Sort

# %%
# URL de l'application à scraper (ici, Spotify)
url = 'com.spotify.music'

# Extraction des avis via l'API google-play-scraper
avis, _ = reviews(url, # Identifiant de l'application sur le Play Store
                  lang='fr', # Langue des avis (français)
                  country='cm', # Pays des avis (Cameroun)
                  sort=Sort.MOST_RELEVANT, # Trier par pertinence (avis les plus pertinents)
                  count=10000, # Nombre maximal d'avis à récupérer
                  filter_score_with=None # Aucun filtre sur les notes (prendre tous les avis)
                 )

# %%
avis
# Out:
# [{'reviewId': '9b4a4883-43fe-443a-8fc0-e2cee41cdc18',
#   'userName': 'Un utilisateur de Google',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': "J'adore écouté de la musique est cette appli est parfaite !! Il y a de tout c'est génial !! Le seul truc qui dérange c'est que il faut avoir un abonnement pour pouvoir passé les musiques en illimité, écouté dans l'ordre et sans pub. C'est vraiment dommage surtout que je ne suis qu'une enfant et que je ne peux pas payer l'abonnement. Ce serait bien juste de pouvoir passé les musiques illimité. S'il vous plaît 🥺. Sinon, c'est super ! Merci 😊",
#   'score': 4,
#   'thumbsUpCount': 185,
#   'reviewCreatedVersion': '8.9.90.127',
#   'at': datetime.datetime(2024, 11, 10, 12, 15, 9),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '8.9.90.127'},
#  {'reviewId': '6e08ffd3-f8a0-4988-8e95-ae9e50c41b8c',
# ...

# %%
# Conversion des avis récupérés en DataFrame pandas
df = pd.DataFrame.from_records(avis)
df
# Sauvegarde des avis dans un fichier CSV
df.to_csv('scrapped_reviews.csv', index=False, encoding='utf-8-sig', sep=';')
